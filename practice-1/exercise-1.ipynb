# %% [markdown]
# # Exercise instructions
#
# In "data.dat" you will dind measurements and the corresponding time step.
#
# 1. Read the data into Matlab and plot it.
# 2. Make a least squares fit to the funtion f = ax + b.
# 3. For the obtained parameters a and b plor the linear funtion in the
#    same figure.
# 4. Repeat task 1 to 3, but only take the masurements from t<=25.
# 5. The time steps (in seconds) are not given at equally spaced instances
#    (delta(t) is not constant).
#    Interpolate the measurement values such that delta(t)=1s.

# %% [markdown]
# ## Imports

# %%
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Data loading

# %%
data = np.loadtxt('data.dat', comments='%')

# %%
x = data[:, 0]
y = data[:, 1]

# %% [markdown]
# Plotting

# %%
plt.figure()

plt.scatter(x, y, label='some random data')

plt.grid(True)

plt.xlabel('time')
plt.ylabel('some random magnitude')
plt.legend(loc=2);

# %% [markdown]
# ## Exercise 2 and 3

# %% [markdown]
# Courve fitting using linear least squares

# %%
f = np.polyfit(x, y, 1)

# %%
p = np.poly1d(f)

# %%
plt.figure()

plt.scatter(x, y, label='some random data')
plt.plot(x, p(x), c='r', lw=2)

plt.grid(True)

plt.xlabel('time')
plt.ylabel('some random magnitude')
plt.legend(loc=2);

# %% [markdown]
# ## Exercise 4

# %%
mask = x <= 25;

xx = x[mask]
yy = y[mask]

# %%
ff = np.polyfit(xx, yy, 1)

# %%
pp = np.poly1d(ff)

# %%
plt.figure()

plt.scatter(xx, yy, label='some random data')
plt.plot(xx, pp(xx), c='r', lw=2)

plt.grid(True)

plt.xlabel('time')
plt.ylabel('some random magnitude')
plt.legend(loc=2);

# %% [markdown]
# ## Exercise 5

# %%
x_interp = np.linspace(2, 30, 50)

interp_1 = interp1d(x, y, kind='cubic')

# %%
plt.figure()

plt.scatter(x, y, s, label='some random data')
plt.plot(x_interp, interp_1(x_interp), marker='o', c='r', lw=2, label='interpolated data')

plt.grid(True)

plt.xlabel('time')
plt.ylabel('some random magnitude')
plt.legend(loc=2);
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# <ipython-input-58-6e686f6453df> in <module>()
#       1 plt.figure()
#       2
# ----> 3 plt.scatter(x, y, mw=4, label='some random data')
#       4 plt.plot(x_interp, interp_1(x_interp), marker='o', c='r', lw=2, label='interpolated data')
#       5
#
# /Users/pablo/miniconda3/envs/science/lib/python3.5/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3256                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3257                          linewidths=linewidths, verts=verts,
# -> 3258                          edgecolors=edgecolors, data=data, **kwargs)
#    3259     finally:
#    3260         ax.hold(washold)
#
# /Users/pablo/miniconda3/envs/science/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /Users/pablo/miniconda3/envs/science/lib/python3.5/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3867                 )
#    3868         collection.set_transform(mtransforms.IdentityTransform())
# -> 3869         collection.update(kwargs)
#    3870
#    3871         if colors is None:
#
# /Users/pablo/miniconda3/envs/science/lib/python3.5/site-packages/matplotlib/artist.py in update(self, props)
#     857                 func = getattr(self, 'set_' + k, None)
#     858                 if func is None or not six.callable(func):
# --> 859                     raise AttributeError('Unknown property %s' % k)
#     860                 func(v)
#     861             changed = True
#
# AttributeError: Unknown property mw
